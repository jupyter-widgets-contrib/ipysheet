# %%
# %load_ext autoreload
# %autoreload 2

from sheet_issue import SheetIssue

# %%
a = SheetIssue()

# %%
# a.show_sheet()

# %%
a.show_box()
# Out:
# Box(children=(Sheet(cells=(Cell(column_end=0, column_start=0, row_end=0, row_start=0, style={'textAlign': 'cen…

# %%
# a.show_output()

# %%
# a.show_tab_output()

# %%
a.show_tab_box()
